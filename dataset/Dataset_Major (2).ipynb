# %%
# !wget -r -N -c -np https://physionet.org/files/challenge-2019/1.0.0/
# Out:
# --2026-09-06 08:27:30--  https://physionet.org/files/challenge-2019/1.0.0/
# Resolving physionet.org (physionet.org)... 18.25.8.254
# Connecting to physionet.org (physionet.org)|18.25.8.254|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]   1.41K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2026-09-06 08:27:31 (213 MB/s) - ‘physionet.org/files/challenge-2019/1.0.0/index.html’ saved [1446]
#
# Loading robots.txt; please ignore errors.
# --2026-09-06 08:27:31--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# ...

# %%
# !wget -r -N -c -np https://physionet.org/files/challenge-2019/1.0.0/training/
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 6000 (5.9K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p119501.psv’
#
# physionet.org/files 100%[===================>]   5.86K  --.-KB/s    in 0s
#
# 2026-09-06 10:02:22 (1.79 GB/s) - ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p119501.psv’ saved [6000/6000]
#
# --2026-09-06 10:02:22--  https://physionet.org/files/challenge-2019/1.0.0/training/training_setB/p119502.psv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3146 (3.1K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p119502.psv’
#
# physionet.org/files 100%[===================>]   3.07K  --.-KB/s    in 0s
#
# 2026-09-06 10:02:22 (1.16 GB/s) - ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p119502.psv’ saved [3146/3146]
#
# ...

# %%
# !find / -name "p100001.psv" 2>/dev/null

# %%
import glob

files = glob.glob('physionet.org/files/challenge-2019/1.0.0/training/training_setA/*.psv') + \
        glob.glob('physionet.org/files/challenge-2019/1.0.0/training/training_setB/*.psv')
print(f"Total .psv files: {len(files)}")
# Out:
# Total .psv files: 0

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !find / -maxdepth 6 -iname "physionet.org" -type d 2>/dev/null

# %%
# !ls -la /content/
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Sep  4 13:25 .
# drwxr-xr-x 1 root root 4096 Sep 13 13:27 ..
# drwxr-xr-x 4 root root 4096 Sep  4 13:25 .config
# drwxr-xr-x 1 root root 4096 Sep  4 13:25 sample_data

# %%
# !wget -r -N -c -np https://physionet.org/files/challenge-2019/1.0.0/training/
# Out:
# Streaming output truncated to the last 5000 lines.
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p103311.psv’
#
# physionet.org/files 100%[===================>]   2.55K  --.-KB/s    in 0s
#
# 2026-09-13 15:59:26 (1.00 GB/s) - ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p103311.psv’ saved [2608/2608]
#
# --2026-09-13 15:59:26--  https://physionet.org/files/challenge-2019/1.0.0/training/training_setB/p103312.psv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3188 (3.1K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p103312.psv’
#
# physionet.org/files 100%[===================>]   3.11K  --.-KB/s    in 0s
#
# 2026-09-13 15:59:26 (1.08 GB/s) - ‘physionet.org/files/challenge-2019/1.0.0/training/training_setB/p103312.psv’ saved [3188/3188]
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/physionet.org/files/challenge-2019/1.0.0/training /content/drive/MyDrive/healthtwin_sepsis_data

# %%
# !find /content/drive/MyDrive/healthtwin_sepsis_data -name "*.psv" | wc -l
# Out:
# 24146

# %%
from google.colab import drive
drive.mount('/content/drive')

# !wget -r -N -c -np https://physionet.org/files/challenge-2019/1.0.0/training/
# Out:
# Streaming output truncated to the last 5000 lines.
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/training/training_setA/p013083.psv’
#
# physionet.org/files 100%[===================>]   7.98K  --.-KB/s    in 0s
#
# 2026-09-16 05:59:48 (2.56 GB/s) - ‘physionet.org/files/challenge-2019/1.0.0/training/training_setA/p013083.psv’ saved [8170/8170]
#
# --2026-09-16 05:59:48--  https://physionet.org/files/challenge-2019/1.0.0/training/training_setA/p013084.psv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9269 (9.1K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2019/1.0.0/training/training_setA/p013084.psv’
#
# physionet.org/files 100%[===================>]   9.05K  --.-KB/s    in 0s
#
# 2026-09-16 05:59:48 (1.90 GB/s) - ‘physionet.org/files/challenge-2019/1.0.0/training/training_setA/p013084.psv’ saved [9269/9269]
#
# ...

# %%
# !cp -r /content/physionet.org/files/challenge-2019/1.0.0/training/* /content/drive/MyDrive/healthtwin_sepsis_data/
# Out:
# ^C

# %%
# !find /content/drive/MyDrive/healthtwin_sepsis_data -name "*.psv" | wc -l
# Out:
# 24146

# %%
# !cp -r /content/physionet.org/files/challenge-2019/1.0.0/training/* /content/drive/MyDrive/healthtwin_sepsis_data/
# Out:
# cp: cannot stat '/content/physionet.org/files/challenge-2019/1.0.0/training/*': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/physionet.org/files/challenge-2019/1.0.0/training
# !cp -r /content/drive/MyDrive/healthtwin_sepsis_data/* /content/physionet.org/files/challenge-2019/1.0.0/training/

# %%
# !wget -r -N -c -np https://physionet.org/files/challenge-2019/1.0.0/training/
# Out:
# Streaming output truncated to the last 5000 lines.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2026-09-16 16:34:13--  https://physionet.org/files/challenge-2019/1.0.0/training/training_setA/p011065.psv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2026-09-16 16:34:13--  https://physionet.org/files/challenge-2019/1.0.0/training/training_setA/p011066.psv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# --2026-09-16 16:34:13--  https://physionet.org/files/challenge-2019/1.0.0/training/training_setA/p011067.psv
# Reusing existing connection to physionet.org:443.
# ...

# %%
# !cp -r /content/physionet.org/files/challenge-2019/1.0.0/training/* /content/drive/MyDrive/healthtwin_sepsis_data/

# %%
# !find /content/drive/MyDrive/healthtwin_sepsis_data -name "*.psv" | wc -l
# Out:
# 24146
